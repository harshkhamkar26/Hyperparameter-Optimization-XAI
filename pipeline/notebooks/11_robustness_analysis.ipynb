# %% [markdown]
# # 11 — Robustness Analysis
# **Purpose:** Evaluate optimized approaches across repeated stratified runs/random seeds and report mean, variability, and confidence intervals where appropriate.
